# %%
import simpy
import random
import statistics

# %% [markdown]
# # Basic Simulation

# %%
# Containers
    # crude container
crudeCon_capacity = 1000
crudeCon_initial = 500
    # product container
prodCon_capacity = 500
#-------------------------------------------------
class Factory:
    def __init__(self, env):
        self.env = env
        
        # 定义两个容器 (Container)
        # 一个用来存放原材料，一个用来存放加工后的材料
        self.crudeCon = simpy.Container(env, capacity=crudeCon_capacity, init = crudeCon_initial)
        self.prodCon = simpy.Container(env ,capacity = prodCon_capacity, init = 0)
        
    # 定义一台 machine
    # [流程]: 从原料勇气中取出 2 个原材料，加工成 1 个产品，并放入产品容器
    # [时间]: 1 个时间单位
    def maker(self):
        while True:
            yield self.crudeCon.get(2)
            process_time = 1
            yield self.env.timeout(process_time)
            yield self.prodCon.put(1)
#-------------------------------------------------
# 创建环境、工厂对象
env = simpy.Environment()
factory = Factory(env)
# 添加一台 machine
env.process(factory.maker())
# 模拟到第 50 个时间单位
env.run(until = 100)

print(f'%d products are finished!' % factory.prodCon.level)
# Out:
# 99 products are finished!

# %%
simpy.Resource?
# Out:
# Init signature: simpy.Resource(env: simpy.core.Environment, capacity: int = 1)
# Docstring:
# Resource with *capacity* of usage slots that can be requested by
# processes.
#
# If all slots are taken, requests are enqueued. Once a usage request is
# released, a pending request will be triggered.
#
# The *env* parameter is the :class:`~simpy.core.Environment` instance the
# resource is bound to.
# File:           ~/anaconda3/lib/python3.9/site-packages/simpy/resources/resource.py
# Type:           type
# Subclasses:     PriorityResource

# %%
# Number of parallel machines
num_maker = 2
num_painter = 3
num_assembler = 1

# Critial Stock Level (when reach, 触发警报并订货)
wood_critial_stock = 100
wood_order_amount = 300
wood_order_leadTime = 16

elec_critial_stock = 30
elec_order_amount = 50
elec_order_leadTime = 8 

class Guitar_Factory:
    def __init__(self, env):
        self.env = env
        
        # 定义五个容器 (Container)
        self.woodCon = simpy.Container(env, capacity=1000, init = 500)
        self.prePaintCon = simpy.Container(env, capacity=100, init = 0)
        self.postPaintCon = simpy.Container(env, capacity=200, init = 0)
        self.elecCon = simpy.Container(env, capacity=100, init = 100)
        self.guitarCon = simpy.Container(env ,capacity=500, init = 0)
    # -----------------------------------------------------
    # 定义 machine
    # maker: 加工木头，制作成琴身
    def maker(self):
        while True:
            yield self.woodCon.get(2)
            process_time = random.gauss(1, 0.2)
            yield self.env.timeout(process_time)
            yield self.prePaintCon.put(1)
    # painter: 为琴身涂漆
    def painter(self):
        while True:
            yield self.prePaintCon.get(1)
            process_time = random.gauss(4, 1)
            yield self.env.timeout(process_time)
            yield self.postPaintCon.put(1)
    # assembler: 组装琴身、电子元件，制作成吉他
    def assembler(self):
        while True:
            yield self.postPaintCon.get(1)
            yield self.elecCon.get(1)
            process_time = 1
            yield self.env.timeout(process_time)
            yield self.guitarCon.put(1)
            
    # -----------------------------------------------------
    # 生成多个 parallel machines
    def makerGen(self): # maker Generator
        for i in range(num_maker):
            yield self.env.process(self.maker())
    def painterGen(self): # painter Generator
        for i in range(num_painter):
            yield self.env.process(self.painter())
    def assemblerGen(self): # assembler Generator
        for i in range(num_assembler):
            yield self.env.process(self.assembler())
    
    # -----------------------------------------------------
    # 定义库存报警
    def wood_stock_control(self):
        yield self.env.timeout(0)
        while True:
            if self.woodCon.level <= wood_critial_stock:
                # 触发警报
                print('Wood stock bellow critical level ({0}) at time {1}'.\
                    format(self.woodCon.level, int(self.env.now)))
                # 联系供应商，购买 300 个木材
                print('Calling wood supplier...')
                yield self.env.timeout(wood_order_leadTime)
                print('Wood supplier arrives at time {0}'.format(int(self.env.now)))
                yield self.woodCon.put(wood_order_amount)
                print('New wood stock is {0}'.format(self.woodCon.level))
                # 进货一次之后，至少再等 8 个时间单位才能重新检查库存
                yield self.env.timeout(8)
            else:
                # 如果没有触发警报，就每隔 1 个时间单位检查一次库存
                yield self.env.timeout(1)
    
    def elec_stock_control(self):
        yield self.env.timeout(0)
        while True:
            if self.elecCon.level <= elec_critial_stock:
                print('Elec stock bellow critical level ({0}) at time {1}'.\
                    format(self.woodCon.level, int(self.env.now)))
                print('Calling elec supplier...')
                yield self.env.timeout(16)
                print('Elec supplier arrives at time {0}'.format(int(self.env.now)))
                yield self.woodCon.put(50)
                print('New elec stock is {0}'.format(self.woodCon.level))
                yield self.env.timeout(8)
            else:
                yield self.env.timeout(1)
#-------------------------------------------------
# 创建环境、工厂对象
env = simpy.Environment()
factory = Guitar_Factory(env)
# 添加三台 machine
env.process(factory.maker())
env.process(factory.painter())
env.process(factory.assembler())
# 模拟到第 50 个时间单位
env.run(until = 50)

print(f'Pre-paint Container has %d bodies ready to be painted' % factory.prePaintCon.level)
print(f'Post-paint Container has %d bodies ready to be assembled' % factory.postPaintCon.level)
print(f'%d products are finished!' % factory.guitarCon.level)
# Out:
# Pre-paint Container has 36 bodies ready to be painted
# Post-paint Container has 0 bodies ready to be assembled
# 11 products are finished!

# %%
wait_times = []

class Theater(object):
    def __init__(self, env, num_cashiers):
        self.env = env
        self.cashier = simpy.Resource(env, num_cashiers)

    def purchase_ticket(self, moviegoer):
        yield self.env.timeout(random.randint(1, 3))

def go_to_movies(env, moviegoer, theater):
    # Moviegoer arrives at the theater
    arrival_time = env.now

    with theater.cashier.request() as request:
        yield request
        yield env.process(theater.purchase_ticket(moviegoer))

    # Moviegoer heads into the theater
    wait_times.append(env.now - arrival_time)

def run_theater(env, num_cashiers):
    theater = Theater(env, num_cashiers)

    # 假设一开始电影院里有3个人
    for moviegoer in range(3):
        env.process(go_to_movies(env, moviegoer, theater))

    # 电影院里的人不断增加（每0.2分钟增加一个人）
    while True:
        yield env.timeout(0.20)
        moviegoer += 1
        env.process(go_to_movies(env, moviegoer, theater))

# %%
 # Setup
random.seed(42)
num_cashiers = 5

# Run the simulation
env = simpy.Environment()
env.process(run_theater(env, num_cashiers))
env.run(until=90)

# View the results
mins, secs = get_average_wait_time(wait_times)
print(
    "Running simulation...",
    f"\nThe average wait time is {mins} minutes and {secs} seconds.",
)
# Out:
# At 0, 0 enters the queue
# At 0, 1 enters the queue
# At 0, 2 enters the queue
# At 0, 0 enters the cashier
# At 0, 1 enters the cashier
# At 0, 2 enters the cashier
# At 0.2, 3 enters the queue
# At 0.2, 3 enters the cashier
# At 0.4, 4 enters the queue
# At 0.4, 4 enters the cashier
# At 0.6000000000000001, 5 enters the queue
# At 0.8, 6 enters the queue
# At 1.0, 7 enters the queue
# At 1, 5 enters the cashier
# At 1, 6 enters the cashier
# At 1.2, 8 enters the queue
# At 1.4, 9 enters the queue
# At 1.5999999999999999, 10 enters the queue
# At 1.7999999999999998, 11 enters the queue
# At 1.9999999999999998, 12 enters the queue
# At 2, 7 enters the cashier
# At 2, 8 enters the cashier
# At 2.1999999999999997, 13 enters the queue
# At 2.4, 14 enters the queue
# At 2.4, 9 enters the cashier
# At 2.6, 15 enters the queue
# At 2.8000000000000003, 16 enters the queue
# At 3, 10 enters the cashier
# At 3, 11 enters the cashier
# At 3.0000000000000004, 17 enters the queue
# At 3.2, 12 enters the cashier
# At 3.2000000000000006, 18 enters the queue
# At 3.4, 13 enters the cashier
# At 3.400000000000001, 19 enters the queue
# At 3.600000000000001, 20 enters the queue
# At 3.800000000000001, 21 enters the queue
# At 4.000000000000001, 22 enters the queue
# At 4.200000000000001, 23 enters the queue
# At 4.4, 14 enters the cashier
# At 4.400000000000001, 24 enters the queue
# At 4.600000000000001, 25 enters the queue
# At 4.800000000000002, 26 enters the queue
# At 5, 15 enters the cashier
# At 5.000000000000002, 27 enters the queue
# At 5.200000000000002, 28 enters the queue
# At 5.400000000000002, 29 enters the queue
# At 5.600000000000002, 30 enters the queue
# At 5.8000000000000025, 31 enters the queue
# At 6, 16 enters the cashier
# At 6, 17 enters the cashier
# At 6.000000000000003, 32 enters the queue
# At 6.2, 18 enters the cashier
# At 6.200000000000003, 33 enters the queue
# At 6.400000000000003, 34 enters the queue
# At 6.600000000000003, 35 enters the queue
# At 6.800000000000003, 36 enters the queue
# At 7, 19 enters the cashier
# At 7, 20 enters the cashier
# At 7, 21 enters the cashier
# At 7.0000000000000036, 37 enters the queue
# At 7.2, 22 enters the cashier
# At 7.200000000000004, 38 enters the queue
# At 7.4, 23 enters the cashier
# At 7.400000000000004, 39 enters the queue
# At 7.600000000000004, 40 enters the queue
# At 7.800000000000004, 41 enters the queue
# At 8, 24 enters the cashier
# At 8, 25 enters the cashier
# At 8.000000000000004, 42 enters the queue
# At 8.200000000000003, 43 enters the queue
# At 8.4, 26 enters the cashier
# At 8.400000000000002, 44 enters the queue
# At 8.600000000000001, 45 enters the queue
# At 8.8, 46 enters the queue
# At 9.0, 47 enters the queue
# At 9, 27 enters the cashier
# At 9.2, 48 enters the queue
# At 9.399999999999999, 49 enters the queue
# At 9.599999999999998, 50 enters the queue
# At 9.799999999999997, 51 enters the queue
# At 9.999999999999996, 52 enters the queue
# At 10, 28 enters the cashier
# At 10.199999999999996, 53 enters the queue
# At 10.2, 29 enters the cashier
# At 10.399999999999995, 54 enters the queue
# At 10.599999999999994, 55 enters the queue
# At 10.799999999999994, 56 enters the queue
# At 10.999999999999993, 57 enters the queue
# At 11, 30 enters the cashier
# At 11.199999999999992, 58 enters the queue
# At 11.399999999999991, 59 enters the queue
# At 11.4, 31 enters the cashier
# At 11.59999999999999, 60 enters the queue
# At 11.79999999999999, 61 enters the queue
# At 11.99999999999999, 62 enters the queue
# At 12, 32 enters the cashier
# At 12.199999999999989, 63 enters the queue
# At 12.399999999999988, 64 enters the queue
# At 12.4, 33 enters the cashier
# At 12.599999999999987, 65 enters the queue
# At 12.799999999999986, 66 enters the queue
# At 12.999999999999986, 67 enters the queue
# At 13, 34 enters the cashier
# At 13, 35 enters the cashier
# At 13.199999999999985, 68 enters the queue
# At 13.2, 36 enters the cashier
# At 13.399999999999984, 69 enters the queue
# At 13.599999999999984, 70 enters the queue
# At 13.799999999999983, 71 enters the queue
# At 13.999999999999982, 72 enters the queue
# At 14, 37 enters the cashier
# At 14, 38 enters the cashier
# At 14.199999999999982, 73 enters the queue
# At 14.2, 39 enters the cashier
# At 14.39999999999998, 74 enters the queue
# At 14.59999999999998, 75 enters the queue
# At 14.79999999999998, 76 enters the queue
# At 14.999999999999979, 77 enters the queue
# At 15, 40 enters the cashier
# At 15.199999999999978, 78 enters the queue
# At 15.399999999999977, 79 enters the queue
# At 15.4, 41 enters the cashier
# At 15.599999999999977, 80 enters the queue
# At 15.799999999999976, 81 enters the queue
# At 15.999999999999975, 82 enters the queue
# At 16, 42 enters the cashier
# At 16.199999999999974, 83 enters the queue
# At 16.2, 43 enters the cashier
# At 16.399999999999974, 84 enters the queue
# At 16.4, 44 enters the cashier
# At 16.599999999999973, 85 enters the queue
# At 16.799999999999972, 86 enters the queue
# At 16.99999999999997, 87 enters the queue
# At 17, 45 enters the cashier
# At 17, 46 enters the cashier
# At 17, 47 enters the cashier
# At 17.19999999999997, 88 enters the queue
# At 17.39999999999997, 89 enters the queue
# At 17.4, 48 enters the cashier
# At 17.59999999999997, 90 enters the queue
# At 17.79999999999997, 91 enters the queue
# At 17.999999999999968, 92 enters the queue
# At 18, 49 enters the cashier
# At 18, 50 enters the cashier
# At 18.199999999999967, 93 enters the queue
# At 18.2, 51 enters the cashier
# At 18.399999999999967, 94 enters the queue
# At 18.599999999999966, 95 enters the queue
# At 18.799999999999965, 96 enters the queue
# At 18.999999999999964, 97 enters the queue
# At 19, 52 enters the cashier
# At 19.199999999999964, 98 enters the queue
# At 19.399999999999963, 99 enters the queue
# At 19.4, 53 enters the cashier
# At 19.599999999999962, 100 enters the queue
# At 19.79999999999996, 101 enters the queue
# At 19.99999999999996, 102 enters the queue
# At 20, 54 enters the cashier
# At 20, 55 enters the cashier
# At 20.19999999999996, 103 enters the queue
# At 20.2, 56 enters the cashier
# At 20.39999999999996, 104 enters the queue
# At 20.59999999999996, 105 enters the queue
# At 20.799999999999958, 106 enters the queue
# At 20.999999999999957, 107 enters the queue
# At 21, 57 enters the cashier
# At 21.199999999999957, 108 enters the queue
# At 21.2, 58 enters the cashier
# At 21.399999999999956, 109 enters the queue
# At 21.599999999999955, 110 enters the queue
# At 21.799999999999955, 111 enters the queue
# At 21.999999999999954, 112 enters the queue
# At 22, 59 enters the cashier
# At 22.199999999999953, 113 enters the queue
# At 22.2, 60 enters the cashier
# At 22.399999999999952, 114 enters the queue
# At 22.4, 61 enters the cashier
# At 22.59999999999995, 115 enters the queue
# At 22.79999999999995, 116 enters the queue
# At 22.99999999999995, 117 enters the queue
# At 23, 62 enters the cashier
# At 23, 63 enters the cashier
# At 23.19999999999995, 118 enters the queue
# At 23.39999999999995, 119 enters the queue
# At 23.599999999999948, 120 enters the queue
# At 23.799999999999947, 121 enters the queue
# At 23.999999999999947, 122 enters the queue
# At 24.199999999999946, 123 enters the queue
# At 24.2, 64 enters the cashier
# At 24.399999999999945, 124 enters the queue
# At 24.599999999999945, 125 enters the queue
# At 24.799999999999944, 126 enters the queue
# At 24.999999999999943, 127 enters the queue
# At 25, 65 enters the cashier
# At 25, 66 enters the cashier
# At 25.199999999999942, 128 enters the queue
# At 25.39999999999994, 129 enters the queue
# At 25.4, 67 enters the cashier
# At 25.59999999999994, 130 enters the queue
# At 25.79999999999994, 131 enters the queue
# At 25.99999999999994, 132 enters the queue
# At 26, 68 enters the cashier
# At 26, 69 enters the cashier
# At 26.19999999999994, 133 enters the queue
# At 26.399999999999938, 134 enters the queue
# At 26.4, 70 enters the cashier
# At 26.599999999999937, 135 enters the queue
# At 26.799999999999937, 136 enters the queue
# At 26.999999999999936, 137 enters the queue
# At 27, 71 enters the cashier
# At 27.199999999999935, 138 enters the queue
# At 27.2, 72 enters the cashier
# At 27.399999999999935, 139 enters the queue
# At 27.4, 73 enters the cashier
# At 27.599999999999934, 140 enters the queue
# At 27.799999999999933, 141 enters the queue
# At 27.999999999999932, 142 enters the queue
# At 28, 74 enters the cashier
# At 28.199999999999932, 143 enters the queue
# At 28.2, 75 enters the cashier
# At 28.39999999999993, 144 enters the queue
# At 28.4, 76 enters the cashier
# At 28.59999999999993, 145 enters the queue
# At 28.79999999999993, 146 enters the queue
# At 28.99999999999993, 147 enters the queue
# At 29, 77 enters the cashier
# At 29, 78 enters the cashier
# At 29, 79 enters the cashier
# At 29.19999999999993, 148 enters the queue
# At 29.399999999999928, 149 enters the queue
# At 29.599999999999927, 150 enters the queue
# At 29.799999999999926, 151 enters the queue
# At 29.999999999999925, 152 enters the queue
# At 30.199999999999925, 153 enters the queue
# At 30.2, 80 enters the cashier
# At 30.399999999999924, 154 enters the queue
# At 30.4, 81 enters the cashier
# At 30.599999999999923, 155 enters the queue
# At 30.799999999999923, 156 enters the queue
# At 30.999999999999922, 157 enters the queue
# At 31, 82 enters the cashier
# At 31, 83 enters the cashier
# At 31.19999999999992, 158 enters the queue
# At 31.2, 84 enters the cashier
# At 31.39999999999992, 159 enters the queue
# At 31.59999999999992, 160 enters the queue
# At 31.79999999999992, 161 enters the queue
# At 31.99999999999992, 162 enters the queue
# At 32, 85 enters the cashier
# At 32, 86 enters the cashier
# At 32.19999999999992, 163 enters the queue
# At 32.39999999999992, 164 enters the queue
# At 32.4, 87 enters the cashier
# At 32.59999999999992, 165 enters the queue
# At 32.799999999999926, 166 enters the queue
# At 32.99999999999993, 167 enters the queue
# At 33, 88 enters the cashier
# At 33.19999999999993, 168 enters the queue
# At 33.399999999999935, 169 enters the queue
# At 33.59999999999994, 170 enters the queue
# At 33.79999999999994, 171 enters the queue
# At 33.99999999999994, 172 enters the queue
# At 34, 89 enters the cashier
# At 34.199999999999946, 173 enters the queue
# At 34.2, 90 enters the cashier
# At 34.39999999999995, 174 enters the queue
# At 34.59999999999995, 175 enters the queue
# At 34.799999999999955, 176 enters the queue
# At 34.99999999999996, 177 enters the queue
# At 35, 91 enters the cashier
# At 35, 92 enters the cashier
# At 35.19999999999996, 178 enters the queue
# At 35.39999999999996, 179 enters the queue
# At 35.4, 93 enters the cashier
# At 35.599999999999966, 180 enters the queue
# At 35.79999999999997, 181 enters the queue
# At 35.99999999999997, 182 enters the queue
# At 36, 94 enters the cashier
# At 36, 95 enters the cashier
# At 36.199999999999974, 183 enters the queue
# At 36.39999999999998, 184 enters the queue
# At 36.59999999999998, 185 enters the queue
# At 36.79999999999998, 186 enters the queue
# At 36.999999999999986, 187 enters the queue
# At 37, 96 enters the cashier
# At 37.19999999999999, 188 enters the queue
# At 37.2, 97 enters the cashier
# At 37.39999999999999, 189 enters the queue
# At 37.599999999999994, 190 enters the queue
# At 37.8, 191 enters the queue
# At 38.0, 192 enters the queue
# At 38, 98 enters the cashier
# At 38, 99 enters the cashier
# At 38.2, 193 enters the queue
# At 38.4, 100 enters the cashier
# At 38.400000000000006, 194 enters the queue
# At 38.60000000000001, 195 enters the queue
# At 38.80000000000001, 196 enters the queue
# At 39, 101 enters the cashier
# At 39.000000000000014, 197 enters the queue
# At 39.2, 102 enters the cashier
# At 39.20000000000002, 198 enters the queue
# At 39.40000000000002, 199 enters the queue
# At 39.60000000000002, 200 enters the queue
# At 39.800000000000026, 201 enters the queue
# At 40, 103 enters the cashier
# At 40, 104 enters the cashier
# At 40.00000000000003, 202 enters the queue
# At 40.20000000000003, 203 enters the queue
# At 40.400000000000034, 204 enters the queue
# At 40.60000000000004, 205 enters the queue
# At 40.80000000000004, 206 enters the queue
# At 41, 105 enters the cashier
# At 41.00000000000004, 207 enters the queue
# At 41.200000000000045, 208 enters the queue
# At 41.4, 106 enters the cashier
# At 41.40000000000005, 209 enters the queue
# At 41.60000000000005, 210 enters the queue
# At 41.800000000000054, 211 enters the queue
# At 42, 107 enters the cashier
# At 42.00000000000006, 212 enters the queue
# At 42.2, 108 enters the cashier
# At 42.20000000000006, 213 enters the queue
# At 42.4, 109 enters the cashier
# At 42.40000000000006, 214 enters the queue
# At 42.600000000000065, 215 enters the queue
# At 42.80000000000007, 216 enters the queue
# At 43, 110 enters the cashier
# At 43, 111 enters the cashier
# At 43, 112 enters the cashier
# At 43.00000000000007, 217 enters the queue
# At 43.2, 113 enters the cashier
# At 43.200000000000074, 218 enters the queue
# At 43.40000000000008, 219 enters the queue
# At 43.60000000000008, 220 enters the queue
# At 43.80000000000008, 221 enters the queue
# At 44, 114 enters the cashier
# At 44.000000000000085, 222 enters the queue
# At 44.2, 115 enters the cashier
# At 44.20000000000009, 223 enters the queue
# At 44.4, 116 enters the cashier
# At 44.40000000000009, 224 enters the queue
# At 44.600000000000094, 225 enters the queue
# At 44.8000000000001, 226 enters the queue
# At 45, 117 enters the cashier
# At 45, 118 enters the cashier
# At 45.0000000000001, 227 enters the queue
# At 45.2000000000001, 228 enters the queue
# At 45.400000000000105, 229 enters the queue
# At 45.60000000000011, 230 enters the queue
# At 45.80000000000011, 231 enters the queue
# At 46, 119 enters the cashier
# At 46.000000000000114, 232 enters the queue
# At 46.20000000000012, 233 enters the queue
# At 46.4, 120 enters the cashier
# At 46.40000000000012, 234 enters the queue
# At 46.60000000000012, 235 enters the queue
# At 46.800000000000125, 236 enters the queue
# At 47, 121 enters the cashier
# At 47.00000000000013, 237 enters the queue
# At 47.2, 122 enters the cashier
# At 47.20000000000013, 238 enters the queue
# At 47.400000000000134, 239 enters the queue
# At 47.600000000000136, 240 enters the queue
# At 47.80000000000014, 241 enters the queue
# At 48, 123 enters the cashier
# At 48, 124 enters the cashier
# At 48.00000000000014, 242 enters the queue
# At 48.200000000000145, 243 enters the queue
# At 48.4, 125 enters the cashier
# At 48.40000000000015, 244 enters the queue
# At 48.60000000000015, 245 enters the queue
# At 48.80000000000015, 246 enters the queue
# At 49, 126 enters the cashier
# At 49.000000000000156, 247 enters the queue
# At 49.2, 127 enters the cashier
# At 49.20000000000016, 248 enters the queue
# At 49.4, 128 enters the cashier
# At 49.40000000000016, 249 enters the queue
# At 49.600000000000165, 250 enters the queue
# At 49.80000000000017, 251 enters the queue
# At 50, 129 enters the cashier
# At 50, 130 enters the cashier
# At 50, 131 enters the cashier
# At 50.00000000000017, 252 enters the queue
# At 50.20000000000017, 253 enters the queue
# At 50.400000000000176, 254 enters the queue
# At 50.60000000000018, 255 enters the queue
# At 50.80000000000018, 256 enters the queue
# At 51.000000000000185, 257 enters the queue
# At 51.20000000000019, 258 enters the queue
# At 51.40000000000019, 259 enters the queue
# At 51.60000000000019, 260 enters the queue
# At 51.800000000000196, 261 enters the queue
# At 52, 132 enters the cashier
# At 52.0000000000002, 262 enters the queue
# At 52.2, 133 enters the cashier
# At 52.2000000000002, 263 enters the queue
# At 52.4, 134 enters the cashier
# At 52.400000000000205, 264 enters the queue
# At 52.60000000000021, 265 enters the queue
# At 52.80000000000021, 266 enters the queue
# At 53, 135 enters the cashier
# At 53, 136 enters the cashier
# At 53.00000000000021, 267 enters the queue
# At 53.200000000000216, 268 enters the queue
# At 53.40000000000022, 269 enters the queue
# At 53.60000000000022, 270 enters the queue
# At 53.800000000000225, 271 enters the queue
# At 54.00000000000023, 272 enters the queue
# At 54.2, 137 enters the cashier
# At 54.20000000000023, 273 enters the queue
# At 54.40000000000023, 274 enters the queue
# At 54.600000000000236, 275 enters the queue
# At 54.80000000000024, 276 enters the queue
# At 55, 138 enters the cashier
# At 55, 139 enters the cashier
# At 55, 140 enters the cashier
# At 55.00000000000024, 277 enters the queue
# At 55.2, 141 enters the cashier
# At 55.200000000000244, 278 enters the queue
# At 55.4, 142 enters the cashier
# At 55.40000000000025, 279 enters the queue
# At 55.60000000000025, 280 enters the queue
# At 55.80000000000025, 281 enters the queue
# At 56, 143 enters the cashier
# At 56.000000000000256, 282 enters the queue
# At 56.2, 144 enters the cashier
# At 56.20000000000026, 283 enters the queue
# At 56.4, 145 enters the cashier
# At 56.40000000000026, 284 enters the queue
# At 56.600000000000264, 285 enters the queue
# At 56.80000000000027, 286 enters the queue
# At 57, 146 enters the cashier
# At 57, 147 enters the cashier
# At 57.00000000000027, 287 enters the queue
# At 57.2, 148 enters the cashier
# At 57.20000000000027, 288 enters the queue
# At 57.400000000000276, 289 enters the queue
# At 57.60000000000028, 290 enters the queue
# At 57.80000000000028, 291 enters the queue
# At 58, 149 enters the cashier
# At 58, 150 enters the cashier
# At 58.000000000000284, 292 enters the queue
# At 58.20000000000029, 293 enters the queue
# At 58.40000000000029, 294 enters the queue
# At 58.60000000000029, 295 enters the queue
# At 58.800000000000296, 296 enters the queue
# At 59, 151 enters the cashier
# At 59.0000000000003, 297 enters the queue
# At 59.2, 152 enters the cashier
# At 59.2000000000003, 298 enters the queue
# At 59.4, 153 enters the cashier
# At 59.400000000000304, 299 enters the queue
# At 59.60000000000031, 300 enters the queue
# At 59.80000000000031, 301 enters the queue
# At 60, 154 enters the cashier
# At 60.00000000000031, 302 enters the queue
# At 60.200000000000315, 303 enters the queue
# At 60.40000000000032, 304 enters the queue
# At 60.60000000000032, 305 enters the queue
# At 60.800000000000324, 306 enters the queue
# At 61, 155 enters the cashier
# At 61, 156 enters the cashier
# At 61.00000000000033, 307 enters the queue
# At 61.2, 157 enters the cashier
# At 61.20000000000033, 308 enters the queue
# At 61.40000000000033, 309 enters the queue
# At 61.600000000000335, 310 enters the queue
# At 61.80000000000034, 311 enters the queue
# At 62, 158 enters the cashier
# At 62.00000000000034, 312 enters the queue
# At 62.200000000000344, 313 enters the queue
# At 62.4, 159 enters the cashier
# At 62.40000000000035, 314 enters the queue
# At 62.60000000000035, 315 enters the queue
# At 62.80000000000035, 316 enters the queue
# At 63, 160 enters the cashier
# At 63, 161 enters the cashier
# At 63.000000000000355, 317 enters the queue
# At 63.20000000000036, 318 enters the queue
# At 63.40000000000036, 319 enters the queue
# At 63.600000000000364, 320 enters the queue
# At 63.80000000000037, 321 enters the queue
# At 64, 162 enters the cashier
# At 64, 163 enters the cashier
# At 64.00000000000037, 322 enters the queue
# At 64.2, 164 enters the cashier
# At 64.20000000000037, 323 enters the queue
# At 64.40000000000038, 324 enters the queue
# At 64.60000000000038, 325 enters the queue
# At 64.80000000000038, 326 enters the queue
# At 65.00000000000038, 327 enters the queue
# At 65.20000000000039, 328 enters the queue
# At 65.4, 165 enters the cashier
# At 65.40000000000039, 329 enters the queue
# At 65.60000000000039, 330 enters the queue
# At 65.8000000000004, 331 enters the queue
# At 66, 166 enters the cashier
# At 66.0000000000004, 332 enters the queue
# At 66.2, 167 enters the cashier
# At 66.2000000000004, 333 enters the queue
# At 66.4000000000004, 334 enters the queue
# At 66.6000000000004, 335 enters the queue
# At 66.80000000000041, 336 enters the queue
# At 67, 168 enters the cashier
# At 67, 169 enters the cashier
# At 67.00000000000041, 337 enters the queue
# At 67.2, 170 enters the cashier
# At 67.20000000000041, 338 enters the queue
# At 67.40000000000042, 339 enters the queue
# At 67.60000000000042, 340 enters the queue
# At 67.80000000000042, 341 enters the queue
# At 68, 171 enters the cashier
# At 68.00000000000043, 342 enters the queue
# At 68.2, 172 enters the cashier
# At 68.20000000000043, 343 enters the queue
# At 68.4, 173 enters the cashier
# At 68.40000000000043, 344 enters the queue
# At 68.60000000000043, 345 enters the queue
# At 68.80000000000044, 346 enters the queue
# At 69, 174 enters the cashier
# At 69, 175 enters the cashier
# At 69.00000000000044, 347 enters the queue
# At 69.2, 176 enters the cashier
# At 69.20000000000044, 348 enters the queue
# At 69.40000000000045, 349 enters the queue
# At 69.60000000000045, 350 enters the queue
# At 69.80000000000045, 351 enters the queue
# At 70, 177 enters the cashier
# At 70.00000000000045, 352 enters the queue
# At 70.20000000000046, 353 enters the queue
# At 70.40000000000046, 354 enters the queue
# At 70.60000000000046, 355 enters the queue
# At 70.80000000000047, 356 enters the queue
# At 71, 178 enters the cashier
# At 71, 179 enters the cashier
# At 71.00000000000047, 357 enters the queue
# At 71.20000000000047, 358 enters the queue
# At 71.4, 180 enters the cashier
# At 71.40000000000047, 359 enters the queue
# At 71.60000000000048, 360 enters the queue
# At 71.80000000000048, 361 enters the queue
# At 72, 181 enters the cashier
# At 72, 182 enters the cashier
# At 72.00000000000048, 362 enters the queue
# At 72.2, 183 enters the cashier
# At 72.20000000000049, 363 enters the queue
# At 72.40000000000049, 364 enters the queue
# At 72.60000000000049, 365 enters the queue
# At 72.8000000000005, 366 enters the queue
# At 73.0000000000005, 367 enters the queue
# At 73.2000000000005, 368 enters the queue
# At 73.4000000000005, 369 enters the queue
# At 73.6000000000005, 370 enters the queue
# At 73.80000000000051, 371 enters the queue
# At 74, 184 enters the cashier
# At 74, 185 enters the cashier
# At 74.00000000000051, 372 enters the queue
# At 74.20000000000051, 373 enters the queue
# At 74.4, 186 enters the cashier
# At 74.40000000000052, 374 enters the queue
# At 74.60000000000052, 375 enters the queue
# At 74.80000000000052, 376 enters the queue
# At 75, 187 enters the cashier
# At 75, 188 enters the cashier
# At 75.00000000000053, 377 enters the queue
# At 75.2, 189 enters the cashier
# At 75.20000000000053, 378 enters the queue
# At 75.4, 190 enters the cashier
# At 75.40000000000053, 379 enters the queue
# At 75.60000000000053, 380 enters the queue
# At 75.80000000000054, 381 enters the queue
# At 76, 191 enters the cashier
# At 76.00000000000054, 382 enters the queue
# At 76.20000000000054, 383 enters the queue
# At 76.40000000000055, 384 enters the queue
# At 76.60000000000055, 385 enters the queue
# At 76.80000000000055, 386 enters the queue
# At 77, 192 enters the cashier
# At 77, 193 enters the cashier
# At 77, 194 enters the cashier
# At 77.00000000000055, 387 enters the queue
# At 77.20000000000056, 388 enters the queue
# At 77.40000000000056, 389 enters the queue
# At 77.60000000000056, 390 enters the queue
# At 77.80000000000057, 391 enters the queue
# At 78.00000000000057, 392 enters the queue
# At 78.2, 195 enters the cashier
# At 78.20000000000057, 393 enters the queue
# At 78.4, 196 enters the cashier
# At 78.40000000000057, 394 enters the queue
# At 78.60000000000058, 395 enters the queue
# At 78.80000000000058, 396 enters the queue
# At 79, 197 enters the cashier
# At 79, 198 enters the cashier
# At 79.00000000000058, 397 enters the queue
# At 79.2, 199 enters the cashier
# At 79.20000000000059, 398 enters the queue
# At 79.4, 200 enters the cashier
# At 79.40000000000059, 399 enters the queue
# At 79.60000000000059, 400 enters the queue
# At 79.8000000000006, 401 enters the queue
# At 80, 201 enters the cashier
# At 80.0000000000006, 402 enters the queue
# At 80.2, 202 enters the cashier
# At 80.2000000000006, 403 enters the queue
# At 80.4, 203 enters the cashier
# At 80.4000000000006, 404 enters the queue
# At 80.6000000000006, 405 enters the queue
# At 80.80000000000061, 406 enters the queue
# At 81, 204 enters the cashier
# At 81, 205 enters the cashier
# At 81, 206 enters the cashier
# At 81.00000000000061, 407 enters the queue
# At 81.20000000000061, 408 enters the queue
# At 81.4, 207 enters the cashier
# At 81.40000000000062, 409 enters the queue
# At 81.60000000000062, 410 enters the queue
# At 81.80000000000062, 411 enters the queue
# At 82, 208 enters the cashier
# At 82.00000000000063, 412 enters the queue
# At 82.20000000000063, 413 enters the queue
# At 82.4, 209 enters the cashier
# At 82.40000000000063, 414 enters the queue
# At 82.60000000000063, 415 enters the queue
# At 82.80000000000064, 416 enters the queue
# At 83, 210 enters the cashier
# At 83.00000000000064, 417 enters the queue
# At 83.2, 211 enters the cashier
# At 83.20000000000064, 418 enters the queue
# At 83.4, 212 enters the cashier
# At 83.40000000000065, 419 enters the queue
# At 83.60000000000065, 420 enters the queue
# At 83.80000000000065, 421 enters the queue
# At 84, 213 enters the cashier
# At 84, 214 enters the cashier
# At 84.00000000000065, 422 enters the queue
# At 84.20000000000066, 423 enters the queue
# At 84.40000000000066, 424 enters the queue
# At 84.60000000000066, 425 enters the queue
# At 84.80000000000067, 426 enters the queue
# At 85, 215 enters the cashier
# At 85, 216 enters the cashier
# At 85.00000000000067, 427 enters the queue
# At 85.20000000000067, 428 enters the queue
# At 85.4, 217 enters the cashier
# At 85.40000000000067, 429 enters the queue
# At 85.60000000000068, 430 enters the queue
# At 85.80000000000068, 431 enters the queue
# At 86.00000000000068, 432 enters the queue
# At 86.2, 218 enters the cashier
# At 86.20000000000068, 433 enters the queue
# At 86.40000000000069, 434 enters the queue
# At 86.60000000000069, 435 enters the queue
# At 86.8000000000007, 436 enters the queue
# At 87, 219 enters the cashier
# At 87, 220 enters the cashier
# At 87.0000000000007, 437 enters the queue
# At 87.2000000000007, 438 enters the queue
# At 87.4000000000007, 439 enters the queue
# At 87.6000000000007, 440 enters the queue
# At 87.80000000000071, 441 enters the queue
# At 88, 221 enters the cashier
# At 88, 222 enters the cashier
# At 88.00000000000071, 442 enters the queue
# At 88.2, 223 enters the cashier
# At 88.20000000000071, 443 enters the queue
# At 88.4, 224 enters the cashier
# At 88.40000000000072, 444 enters the queue
# At 88.60000000000072, 445 enters the queue
# At 88.80000000000072, 446 enters the queue
# At 89.00000000000072, 447 enters the queue
# At 89.2, 225 enters the cashier
# At 89.20000000000073, 448 enters the queue
# At 89.40000000000073, 449 enters the queue
# At 89.60000000000073, 450 enters the queue
# At 89.80000000000074, 451 enters the queue
# Running simulation...
# The average wait time is 12 minutes and 14 seconds.

# %%
import simpy
import random
import statistics

wait_times = []


class Theater(object):
    def __init__(self, env, num_cashiers, num_servers, num_ushers):
        self.env = env
        self.cashier = simpy.Resource(env, num_cashiers)
        self.server = simpy.Resource(env, num_servers)
        self.usher = simpy.Resource(env, num_ushers)

    def purchase_ticket(self, moviegoer):
        yield self.env.timeout(random.randint(1, 3))

    def check_ticket(self, moviegoer):
        yield self.env.timeout(3 / 60)

    def sell_food(self, moviegoer):
        yield self.env.timeout(random.randint(1, 5))


def go_to_movies(env, moviegoer, theater):
    # Moviegoer arrives at the theater
    arrival_time = env.now

    with theater.cashier.request() as request:
        yield request
        yield env.process(theater.purchase_ticket(moviegoer))

    with theater.usher.request() as request:
        yield request
        yield env.process(theater.check_ticket(moviegoer))

    if random.choice([True, False]):
        with theater.server.request() as request:
            yield request
            yield env.process(theater.sell_food(moviegoer))

    # Moviegoer heads into the theater
    wait_times.append(env.now - arrival_time)


def run_theater(env, num_cashiers, num_servers, num_ushers):
    theater = Theater(env, num_cashiers, num_servers, num_ushers)

    for moviegoer in range(3):
        env.process(go_to_movies(env, moviegoer, theater))

    while True:
        yield env.timeout(0.20)  # Wait a bit before generating a new person

        moviegoer += 1
        env.process(go_to_movies(env, moviegoer, theater))


def get_average_wait_time(wait_times):
    average_wait = statistics.mean(wait_times)
    # Pretty print the results
    minutes, frac_minutes = divmod(average_wait, 1)
    seconds = frac_minutes * 60
    return round(minutes), round(seconds)

# %%
    # Setup
    random.seed(42)
    num_cashiers, num_servers, num_ushers = [11, 6, 6]

    # Run the simulation
    env = simpy.Environment()
    env.process(run_theater(env, num_cashiers, num_servers, num_ushers))
    env.run(until=90)

    # View the results
    mins, secs = get_average_wait_time(wait_times)
    print(
        "Running simulation...",
        f"\nThe average wait time is {mins} minutes and {secs} seconds.",
    )
# Out:
# Running simulation...
# The average wait time is 6 minutes and 24 seconds.
